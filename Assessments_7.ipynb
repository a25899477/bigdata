# %% [markdown]
# <a href="https://colab.research.google.com/github/a25899477/bigdata/blob/master/Assessments_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("readr")
install.packages("ggplot2")
library(readr)
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
dataset <- read.csv("台灣電力公司_火力發電_溫室氣體排放量.csv")

# %%
str(dataset)
# Out:
# 'data.frame':	12 obs. of  4 variables:
#  $ 年度        : int  2015 2015 2015 2016 2016 2016 2017 2017 2017 2018 ...
#  $ 發電方式    : chr  "燃油" "燃氣" "燃煤" "燃油" ...
#  $ 排放量.萬噸.: int  792 2452 5289 773 2591 5683 847 2900 6255 512 ...
#  $ 占比...     : chr  "9.28%" "28.74%" "61.98%" "8.60%" ...

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(showtext)

# %%
showtext.auto(enable=TRUE)

# %%
ggplot(dataset,aes(x=年度,y=排放量.萬噸.))+geom_point()
# Out:
# plot without title

# %%
ggplot(dataset,aes(排放量.萬噸.))+geom_bar()
# Out:
# plot without title

# %%
ggplot(dataset,aes(x=年度,y=排放量.萬噸.))+geom_boxplot()
# Out:
# Warning message:
# “Continuous x aesthetic -- did you forget aes(group=...)?”
# plot without title

# %%
ggplot(dataset,aes(x=年度,y=排放量.萬噸.))+geom_line()
# Out:
# plot without title
