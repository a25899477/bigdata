# %% [markdown]
# <a href="https://colab.research.google.com/github/a25899477/bigdata/blob/master/%E3%80%8Cassessment_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class(1)
# Out:
# [1] "numeric"

# %%
class("HI")
# Out:
# [1] "character"

# %%
class("hi")
# Out:
# [1] "character"

# %%
class(1+2)
# Out:
# [1] "numeric"

# %%
print(1+2)
# Out:
# [1] 3

# %%
1+2
# Out:
# [1] 3

# %%
5+6
# Out:
# [1] 11

# %%
7+8
# Out:
# [1] 15

# %%
111+3
# Out:
# [1] 114

# %%
5+5+5+5+5+5+5+5+5
# Out:
# [1] 45

# %%
+4+4+4+4+4
# Out:
# [1] 20

# %%
5+4-4
# Out:
# [1] 5

# %%
class("gang")
# Out:
# [1] "character"

# %%
print("1+2")
# Out:
# [1] "1+2"

# %%
print("我是帥哥")
# Out:
# [1] "我是帥哥"

# %%
print("ffffffffffff")
# Out:
# [1] "ffffffffffff"

# %%
x <- 175 #身高(cm)
y <- 60  #體重(kg)
BMI <- y/(x/100)^2
BMI
# Out:
# [1] 19.59184

# %%
8>9
# Out:
# [1] FALSE

# %%
20>2
# Out:
# [1] TRUE

# %%
print("pi")
# Out:
# [1] "pi"

# %%
pi+2
# Out:
# [1] 5.141593

# %%
pi
# Out:
# [1] 3.141593

# %%
3*pi
# Out:
# [1] 9.424778

# %%
3^pi
# Out:
# [1] 31.54428

# %%
pi^2
# Out:
# [1] 9.869604

# %%
paste0("我是連翊呈，","我的身高",x,"我的體重",y)
# Out:
# [1] "我是連翊呈，我的身高175我的體重60"
